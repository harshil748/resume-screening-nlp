# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from app.preprocessor import preprocess
from app.matcher import compute_similarity

# %%
sample_text = "Python developer with machine learning, SQL, pandas, and Streamlit experience."
cleaned_text = preprocess(sample_text)
cleaned_text
# Out:
# 'python developer machine learning sql panda streamlit experience'

# %%
documents = [
    preprocess("Python machine learning engineer with NLP experience"),
    preprocess("Frontend developer skilled in React HTML CSS"),
    preprocess("Data analyst using SQL pandas Power BI and Excel"),
]

vectorizer = TfidfVectorizer(ngram_range=(1, 2), max_features=5000)
tfidf_matrix = vectorizer.fit_transform(documents)
tfidf_matrix.shape
# Out:
# (3, 37)

# %%
job_description = "Looking for a Python ML intern with NLP, SQL, and pandas skills."
resume_texts = [
    "Python machine learning intern with NLP and pandas projects.",
    "React developer with HTML, CSS, and Node.js experience.",
    "Data analyst with SQL, Excel, Tableau, and pandas experience.",
]

scores = compute_similarity(job_description, resume_texts)
print(scores)
# Out:
# [0.24783031830873614, 0.0, 0.08521590775806101]
